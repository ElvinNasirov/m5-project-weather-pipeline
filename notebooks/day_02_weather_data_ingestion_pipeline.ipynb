# %%
import requests
import pandas as pd
import time
from datetime import datetime


# -------------------------------
# Helper: Retry logic
# -------------------------------
def make_request(url, params, city_name):
    for attempt in range(3):
        try:
            response = requests.get(url, params=params, timeout=10)

            if response.status_code != 200:
                raise Exception(f"HTTP {response.status_code}")

            data = response.json()

            return data

        except Exception as e:
            print(f"[{city_name}] Attempt {attempt+1} failed: {e}")

            # Exponential backoff: 1s → 2s → 4s
            time.sleep(2 ** attempt)

    raise Exception(f"[{city_name}] Failed after 3 retries")


# -------------------------------
# Fetch Historical Data
# -------------------------------
def fetch_historical(city_name, latitude, longitude, start_date, end_date, variables):
    
    # ✅ Date validation
    if start_date >= end_date:
        raise ValueError("start_date must be before end_date")

    today = datetime.today().strftime("%Y-%m-%d")
    if end_date > today:
        raise ValueError("end_date cannot be in the future")

    url = "https://archive-api.open-meteo.com/v1/archive"

    params = {
        "latitude": latitude,
        "longitude": longitude,
        "start_date": start_date,
        "end_date": end_date,
        "daily": ",".join(variables)
    }

    data = make_request(url, params, city_name)

    # ✅ Check response
    if "daily" not in data:
        raise ValueError(f"[{city_name}] Malformed response: {data}")

    df = pd.DataFrame(data["daily"])

    # ✅ Basic validation
    if df.empty:
        raise ValueError(f"[{city_name}] Empty dataset returned")

    df["time"] = pd.to_datetime(df["time"])
    df["city"] = city_name

    return df


# -------------------------------
# Fetch Forecast Data
# -------------------------------
def fetch_forecast(city_name, latitude, longitude, variables):

    url = "https://api.open-meteo.com/v1/forecast"

    params = {
        "latitude": latitude,
        "longitude": longitude,
        "daily": ",".join(variables)
    }

    data = make_request(url, params, city_name)

    if "daily" not in data:
        raise ValueError(f"[{city_name}] Malformed forecast response: {data}")

    df = pd.DataFrame(data["daily"])

    if df.empty:
        raise ValueError(f"[{city_name}] Empty forecast data")

    df["time"] = pd.to_datetime(df["time"])
    df["city"] = city_name

    return df


# -------------------------------
# Fetch All Cities
# -------------------------------
def fetch_all_cities(cities_config, start_date, end_date, variables):

    all_data = {}

    for city in cities_config:
        name = city["name"]
        lat = city["latitude"]
        lon = city["longitude"]

        print(f"Fetching historical data for {name}...")

        df = fetch_historical(
            name,
            lat,
            lon,
            start_date,
            end_date,
            variables
        )

        all_data[name] = df

        print(f"{name}: {len(df)} rows")

    return all_data

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from ingestion import fetch_historical

df = fetch_historical(
    "Baku",
    40.41,
    49.87,
    "2020-01-01",
    "2022-12-31",
    ["temperature_2m_max", "precipitation_sum"]
)

df.head()
# Out:
#         time  temperature_2m_max  precipitation_sum  city
# 0 2020-01-01                11.4                0.0  Baku
# 1 2020-01-02                 8.6                0.3  Baku
# 2 2020-01-03                 7.6                1.4  Baku
# 3 2020-01-04                 8.4                0.2  Baku
# 4 2020-01-05                 7.7                2.6  Baku

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from ingestion import fetch_historical
from config import CITIES, START_DATE, END_DATE, DAILY_VARIABLES

city = CITIES[0]

df = fetch_historical(
    city_name=city["name"],
    latitude=city["latitude"],
    longitude=city["longitude"],
    start_date=START_DATE,
    end_date=END_DATE,
    variables=DAILY_VARIABLES
)

df.head()
# Out:
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2020-01-01                11.4                 4.4                0.0
# 1 2020-01-02                 8.6                 2.7                0.3
# 2 2020-01-03                 7.6                 3.4                1.4
# 3 2020-01-04                 8.4                 5.7                0.2
# 4 2020-01-05                 7.7                 5.8                2.6
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                11.4                       8.8                         88
# 1                33.0                       3.2                         86
# 2                21.7                       3.3                         84
# 3                22.7                       4.6                         81
# 4                12.6                       6.4                         94
#
#    weather_code  city
# 0             3  Baku
# 1            51  Baku
# 2            51  Baku
# 3            51  Baku
# 4            53  Baku

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df["time"].min(), df["time"].max())
# Out:
# (2192, 9)
# Index(['time', 'temperature_2m_max', 'temperature_2m_min', 'precipitation_sum',
#        'wind_speed_10m_max', 'apparent_temperature_max',
#        'relative_humidity_2m_mean', 'weather_code', 'city'],
#       dtype='object')
# time                         datetime64[ns]
# temperature_2m_max                  float64
# temperature_2m_min                  float64
# precipitation_sum                   float64
# wind_speed_10m_max                  float64
# apparent_temperature_max            float64
# relative_humidity_2m_mean             int64
# weather_code                          int64
# city                                 object
# dtype: object
# 2020-01-01 00:00:00 2025-12-31 00:00:00

# %%
from ingestion import fetch_all_cities

data = fetch_all_cities(
    cities_config=CITIES,
    start_date=START_DATE,
    end_date=END_DATE,
    variables=DAILY_VARIABLES
)

for city_name, df in data.items():
    print(f"{city_name}: {df.shape}, {df['time'].min()} → {df['time'].max()}")
# Out:
# Fetching Baku...
# Baku: 2192 rows
# Fetching Lankaran...
# Lankaran: 2192 rows
# Fetching Guba...
# Guba: 2192 rows
# Fetching Gabala...
# Gabala: 2192 rows
# Fetching Shaki...
# [Shaki] Attempt 1 failed: HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Read timed out. (read timeout=10)
# Shaki: 2192 rows
# Baku: (2192, 9), 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Lankaran: (2192, 9), 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Guba: (2192, 9), 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Gabala: (2192, 9), 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Shaki: (2192, 9), 2020-01-01 00:00:00 → 2025-12-31 00:00:00

# %%
import os
from ingestion import fetch_all_cities
from config import CITIES, START_DATE, END_DATE, DAILY_VARIABLES

# 1. Fetch data
data = fetch_all_cities(
    cities_config=CITIES,
    start_date=START_DATE,
    end_date=END_DATE,
    variables=DAILY_VARIABLES
)

# 2. Quick check
for city_name, df in data.items():
    print(f"""
City: {city_name}
Rows: {len(df)}
Date range: {df['time'].min()} → {df['time'].max()}
Missing values:
{df.isna().sum()}
""")

# 3. Create output folder
os.makedirs("../data/raw/historical", exist_ok=True)

# 4. Save each city as Parquet
for city_name, df in data.items():
    file_path = f"../data/raw/historical/{city_name.lower()}_2020_2025.parquet"
    df.to_parquet(file_path, index=False)
    print(f"Saved: {file_path}")
# Out:
# Fetching Baku...
# Baku: 2192 rows
# Fetching Lankaran...
# Lankaran: 2192 rows
# Fetching Guba...
# Guba: 2192 rows
# Fetching Gabala...
# Gabala: 2192 rows
# Fetching Shaki...
# [Shaki] Rate limit hit. Waiting 1s...
# Shaki: 2192 rows
#
# City: Baku
# Rows: 2192
# Date range: 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Missing values:
# time                         0
# temperature_2m_max           0
# temperature_2m_min           0
# precipitation_sum            0
# wind_speed_10m_max           0
# apparent_temperature_max     0
# relative_humidity_2m_mean    0
# weather_code                 0
# city                         0
# dtype: int64
#
#
# City: Lankaran
# Rows: 2192
# Date range: 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Missing values:
# time                         0
# temperature_2m_max           0
# temperature_2m_min           0
# precipitation_sum            0
# wind_speed_10m_max           0
# apparent_temperature_max     0
# relative_humidity_2m_mean    0
# weather_code                 0
# city                         0
# dtype: int64
#
#
# City: Guba
# Rows: 2192
# Date range: 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Missing values:
# time                         0
# temperature_2m_max           0
# temperature_2m_min           0
# precipitation_sum            0
# wind_speed_10m_max           0
# apparent_temperature_max     0
# relative_humidity_2m_mean    0
# weather_code                 0
# city                         0
# dtype: int64
#
#
# City: Gabala
# Rows: 2192
# Date range: 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Missing values:
# time                         0
# temperature_2m_max           0
# temperature_2m_min           0
# precipitation_sum            0
# wind_speed_10m_max           0
# apparent_temperature_max     0
# relative_humidity_2m_mean    0
# weather_code                 0
# city                         0
# dtype: int64
#
#
# City: Shaki
# Rows: 2192
# Date range: 2020-01-01 00:00:00 → 2025-12-31 00:00:00
# Missing values:
# time                         0
# temperature_2m_max           0
# temperature_2m_min           0
# precipitation_sum            0
# wind_speed_10m_max           0
# apparent_temperature_max     0
# relative_humidity_2m_mean    0
# weather_code                 0
# city                         0
# dtype: int64
#
# Saved: ../data/raw/historical/baku_2020_2025.parquet
# Saved: ../data/raw/historical/lankaran_2020_2025.parquet
# Saved: ../data/raw/historical/guba_2020_2025.parquet
# Saved: ../data/raw/historical/gabala_2020_2025.parquet
# Saved: ../data/raw/historical/shaki_2020_2025.parquet

# %%
from ingestion import fetch_forecast

import os
os.makedirs("../data/raw/forecast", exist_ok=True)

for city in CITIES:
    df_f = fetch_forecast(
        city["name"],
        city["latitude"],
        city["longitude"],
        DAILY_VARIABLES
    )

    file_path = f"../data/raw/forecast/{city['name'].lower()}_forecast.parquet"
    df_f.to_parquet(file_path, index=False)

    print(f"Saved forecast: {file_path}")
# Out:
# Saved forecast: ../data/raw/forecast/baku_forecast.parquet
# Saved forecast: ../data/raw/forecast/lankaran_forecast.parquet
# Saved forecast: ../data/raw/forecast/guba_forecast.parquet
# Saved forecast: ../data/raw/forecast/gabala_forecast.parquet
# Saved forecast: ../data/raw/forecast/shaki_forecast.parquet

# %%
import pandas as pd
import os

path = "../data/raw/forecast"

for file in os.listdir(path):
    if file.endswith(".parquet"):
        print(f"\n📍 File: {file}")
        
        df = pd.read_parquet(os.path.join(path, file))
        
        print(df.head(3))
        print(df.info())
# Out:
# 📍 File: baku_forecast.parquet
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2026-04-23                15.9                 8.2                0.0
# 1 2026-04-24                18.0                 8.0                0.0
# 2 2026-04-25                13.9                 7.7                0.0
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                20.6                      15.8                         88
# 1                22.4                      18.9                         82
# 2                33.7                      10.1                         80
#
#    weather_code  city
# 0            45  Baku
# 1             3  Baku
# 2             3  Baku
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       7 non-null      datetime64[ns]
#  1   temperature_2m_max         7 non-null      float64
#  2   temperature_2m_min         7 non-null      float64
#  3   precipitation_sum          7 non-null      float64
#  4   wind_speed_10m_max         7 non-null      float64
#  5   apparent_temperature_max   7 non-null      float64
#  6   relative_humidity_2m_mean  7 non-null      int64
#  7   weather_code               7 non-null      int64
#  8   city                       7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 636.0+ bytes
# None
#
# 📍 File: gabala_forecast.parquet
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2026-04-23                24.5                10.0                0.0
# 1 2026-04-24                22.8                10.8                0.0
# 2 2026-04-25                21.5                 8.8                0.1
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                18.8                      25.8                         72
# 1                37.8                      22.5                         64
# 2                40.4                      16.9                         53
#
#    weather_code    city
# 0             3  Gabala
# 1             3  Gabala
# 2            61  Gabala
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       7 non-null      datetime64[ns]
#  1   temperature_2m_max         7 non-null      float64
#  2   temperature_2m_min         7 non-null      float64
#  3   precipitation_sum          7 non-null      float64
#  4   wind_speed_10m_max         7 non-null      float64
#  5   apparent_temperature_max   7 non-null      float64
#  6   relative_humidity_2m_mean  7 non-null      int64
#  7   weather_code               7 non-null      int64
#  8   city                       7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 636.0+ bytes
# None
#
# 📍 File: guba_forecast.parquet
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2026-04-23                 7.8                 5.4                0.0
# 1 2026-04-24                11.5                 5.2                0.0
# 2 2026-04-25                 7.8                 2.7                1.2
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                 7.1                       6.6                         99
# 1                 9.1                      10.2                         93
# 2                14.3                       6.0                         88
#
#    weather_code  city
# 0            45  Guba
# 1            45  Guba
# 2            61  Guba
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       7 non-null      datetime64[ns]
#  1   temperature_2m_max         7 non-null      float64
#  2   temperature_2m_min         7 non-null      float64
#  3   precipitation_sum          7 non-null      float64
#  4   wind_speed_10m_max         7 non-null      float64
#  5   apparent_temperature_max   7 non-null      float64
#  6   relative_humidity_2m_mean  7 non-null      int64
#  7   weather_code               7 non-null      int64
#  8   city                       7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 636.0+ bytes
# None
#
# 📍 File: lankaran_forecast.parquet
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2026-04-23                20.6                10.4                0.0
# 1 2026-04-24                18.5                 9.8                0.0
# 2 2026-04-25                21.6                12.5                0.1
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                16.1                      21.7                         83
# 1                14.8                      18.7                         83
# 2                23.8                      20.8                         63
#
#    weather_code      city
# 0            45  Lankaran
# 1             3  Lankaran
# 2             3  Lankaran
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       7 non-null      datetime64[ns]
#  1   temperature_2m_max         7 non-null      float64
#  2   temperature_2m_min         7 non-null      float64
#  3   precipitation_sum          7 non-null      float64
#  4   wind_speed_10m_max         7 non-null      float64
#  5   apparent_temperature_max   7 non-null      float64
#  6   relative_humidity_2m_mean  7 non-null      int64
#  7   weather_code               7 non-null      int64
#  8   city                       7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 636.0+ bytes
# None
#
# 📍 File: shaki_forecast.parquet
#         time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0 2026-04-23                23.3                 8.4                0.0
# 1 2026-04-24                20.2                10.2                0.0
# 2 2026-04-25                19.0                 8.3                0.2
#
#    wind_speed_10m_max  apparent_temperature_max  relative_humidity_2m_mean  \
# 0                12.0                      23.3                         68
# 1                27.7                      19.6                         72
# 2                42.7                      12.3                         55
#
#    weather_code   city
# 0             3  Shaki
# 1             3  Shaki
# 2            61  Shaki
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       7 non-null      datetime64[ns]
#  1   temperature_2m_max         7 non-null      float64
#  2   temperature_2m_min         7 non-null      float64
#  3   precipitation_sum          7 non-null      float64
#  4   wind_speed_10m_max         7 non-null      float64
#  5   apparent_temperature_max   7 non-null      float64
#  6   relative_humidity_2m_mean  7 non-null      int64
#  7   weather_code               7 non-null      int64
#  8   city                       7 non-null      object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 636.0+ bytes
# None
